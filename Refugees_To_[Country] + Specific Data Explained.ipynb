# %%
#Importing Libraries, Setting Env
import json
from pprint import pprint
import pandas as pd
pd.set_option('display.max_columns', 35)

# %% [markdown]
# ### Sample Data Structure

# %%
import json
from pprint import pprint

with open('refugees to DRC per DRC region.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'chartType': 'areaspline',
#  'color': '#3c8dbc',
#  'data': [{'admin_level': 'Province',
#            'centroid_lat': '3.5845154',
#            'centroid_lon': '28.299435',
#            'color': '#3c8dbc',
#            'date': '2018-10-31',
#            'demography_type': '1',
#            'geomaster_id': 4826,
#            'geomaster_name': 'Haut-Uele',
#            'households': '0',
#            'individuals': '49554',
#            'individuals_type': '2',
#            'lat_max': 5.1866504417685,
#            'lat_min': 2.2763552727767,
#            'lon_max': 30.8623046875,
#            'lon_min': 26.55224609375,
#            'month': '10',
#            'numChildren': '0',
#            'population_group_id': '4949, 4768, 5075',
#            'population_groups': [{'id': '4768',
#                                   'name': 'Registered refugees from South '
#                                           'Sudan (rural/dispersed areas, '
# ...

# %%
refugees_info_other_country_mdetail = ['refugees to Kenya per sex', 'refugees to DRC per DRC region', 'refugees to Ethiopia per Ethiopian district','refugees to Kenya per location','refugees to Sudan per Sudanese state','refugees to Uganda per Ugandan district']

with open('refugees to Kenya per location.json') as f:
    data = json.load(f)
    
df = pd.DataFrame(data['data'])
#pprint(data['data'][0])
#print(data['data'][0]['geomaster_name'])

#df_2 = pd.DataFrame()

#for i in range(0, len(data['data'])):
#    for key, value in data['data'][2].items():
#        df_2[key] = value

#df_2.head()

print(df['population_groups'][0])
