# %%
import pandas as pd

refugees_to_kenya = pd.read_json("refugees to Kenya.json")
refugees_to_kenya_per_sex = pd.read_json("refugees to Kenya per sex.json")
refugees_to_kenya_per_location = pd.read_json("refugees to Kenya per location.json")
refugees_to_kenya.head()
# Out:
#              situation_view_id situation_view_name  \
# geoMasterId                  5         South Sudan
# source                       5         South Sudan
# timeseries                   5         South Sudan
#
#                                     situation_view_description  \
# geoMasterId  The situation in South Sudan and neighbouring ...
# source       The situation in South Sudan and neighbouring ...
# timeseries   The situation in South Sudan and neighbouring ...
#
#                                                           data  \
# geoMasterId  {'id': 178, 'name': 'Kenya', 'lat': 0.537253, ...
# source                                                   UNHCR
# timeseries   [{'data_date': '2013-12-31', 'unix_timestamp':...
#
#             title_language_ar  \
# geoMasterId
# source
# timeseries
#
#                                              title_language_en  \
# geoMasterId  Refugees and aylum-seekers from South Sudan - ...
# ...

# %%
print(refugees_to_kenya.data)
# Out:
# geoMasterId    {'id': 178, 'name': 'Kenya', 'lat': 0.537253, ...
# source                                                     UNHCR
# timeseries     [{'data_date': '2013-12-31', 'unix_timestamp':...
# Name: data, dtype: object

# %%
import json
from pprint import pprint

with open('refugees to Kenya.json') as f:
    data_kenya = json.load(f)

#pprint(data)
print(data_kenya['data'])
data_kenya_list = data['data']['timeseries']
# Out:
# {'timeseries': [{'data_date': '2013-12-31', 'unix_timestamp': 1388448000, 'individuals': 46176}, {'data_date': '2014-03-31', 'unix_timestamp': 1396224000, 'individuals': 63211}, {'data_date': '2014-06-30', 'unix_timestamp': 1404086400, 'individuals': 76310}, {'data_date': '2014-09-30', 'unix_timestamp': 1412035200, 'individuals': 87205}, {'data_date': '2014-12-31', 'unix_timestamp': 1419984000, 'individuals': 89474}, {'data_date': '2015-03-31', 'unix_timestamp': 1427760000, 'individuals': 92317}, {'data_date': '2015-06-30', 'unix_timestamp': 1435622400, 'individuals': 95086}, {'data_date': '2015-09-30', 'unix_timestamp': 1443571200, 'individuals': 90240}, {'data_date': '2015-12-31', 'unix_timestamp': 1451520000, 'individuals': 95765}, {'data_date': '2016-01-31', 'unix_timestamp': 1454198400, 'individuals': 96648}, {'data_date': '2016-02-29', 'unix_timestamp': 1456704000, 'individuals': 98142}, {'data_date': '2016-03-31', 'unix_timestamp': 1459382400, 'individuals': 99315}, {'data_dat
# ...

# %%
country_list = ['DRC','Ethiopia','Kenya','Sudan','Uganda']

date = []
timestamp = []
individuals = []
for data in data_kenya_list:
    date.append(data['data_date'])
    timestamp.append(data['unix_timestamp'])
    individuals.append(data['individuals'])
    
refugees_to_kenya_df = pd.DataFrame({'date': date, 'timestamp': timestamp, 'individuals': individuals, 'from': 'South Sudan', 'to': 'Kenya'})
refugees_to_kenya_df.head(10)
# Out:
#          date   timestamp  individuals         from     to
# 0  2013-12-31  1388448000        46176  South Sudan  Kenya
# 1  2014-03-31  1396224000        63211  South Sudan  Kenya
# 2  2014-06-30  1404086400        76310  South Sudan  Kenya
# 3  2014-09-30  1412035200        87205  South Sudan  Kenya
# 4  2014-12-31  1419984000        89474  South Sudan  Kenya
# 5  2015-03-31  1427760000        92317  South Sudan  Kenya
# 6  2015-06-30  1435622400        95086  South Sudan  Kenya
# 7  2015-09-30  1443571200        90240  South Sudan  Kenya
# 8  2015-12-31  1451520000        95765  South Sudan  Kenya
# 9  2016-01-31  1454198400        96648  South Sudan  Kenya

# %%
refugees_to_kenya_df['Year']=[d.split('-')[0] for d in refugees_to_kenya_df.date]
refugees_to_kenya_df['Month']=[d.split('-')[1] for d in refugees_to_kenya_df.date]
refugees_to_kenya_df['Day']=[d.split('-')[2] for d in refugees_to_kenya_df.date]
refugees_to_kenya_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-54-229b8d552aa6> in <module>()
#       4 refugees_to_kenya_df.head()
#       5
# ----> 6 south_sudan_violence_data.to_csv("refugees_to_kenya_cleaned.csv", sep=',')
#
# NameError: name 'south_sudan_violence_data' is not defined

# %%
refugees_to_kenya_df.to_csv("refugees_to_kenya_cleaned.csv", sep=',')

# %%
refugees_to_kenya_per_sex.head()
# Out:
#    situation_view_id situation_view_name  \
# 0                  5         South Sudan
#
#                           situation_view_description  \
# 0  The situation in South Sudan and neighbouring ...
#
#                                                 data  population_group_id  \
# 0  {'geomaster_name': 'Kenya', 'geomaster_id': '1...                 4949
#
#   title_language_ar title_language_en title_language_es title_language_fr  \
# 0                          Demography
#
#   subtitle_language_ar                               subtitle_language_en  \
# 0                       Demographic data may not be available from eve...
#
#   subtitle_language_es subtitle_language_fr limit    color frequency  \
# 0                                                  #3c8dbc       day
#
#     chartType
# 0  areaspline

# %%
refugees_to_kenya_per_location.head()
# Out:
#    situation_view_id situation_view_name  \
# 0                  5         South Sudan
# 1                  5         South Sudan
# 2                  5         South Sudan
#
#                           situation_view_description  \
# 0  The situation in South Sudan and neighbouring ...
# 1  The situation in South Sudan and neighbouring ...
# 2  The situation in South Sudan and neighbouring ...
#
#                                                 data title_language_ar  \
# 0  {'geomaster_name': 'Turkana', 'geomaster_id': ...
# 1  {'geomaster_name': 'Nairobi', 'geomaster_id': ...
# 2  {'geomaster_name': 'Garissa', 'geomaster_id': ...
#
#      title_language_en title_language_es title_language_fr  \
# 0  Breakdown by County
# 1  Breakdown by County
# 2  Breakdown by County
#
#   subtitle_language_ar subtitle_language_en subtitle_language_es  \
# 0
# 1
# 2
#
#   subtitle_language_fr limit    color frequency   chartType
# 0                             #3c8dbc       day  areaspline
# ...

# %%
import json
from pprint import pprint

with open('refugees to Kenya per location.json') as f:
    data = json.load(f)

pprint(data['data'])
# Out:
# [{'admin_level': 'District',
#   'centroid_lat': '3.0398871',
#   'centroid_lon': '35.6207049',
#   'color': '#3c8dbc',
#   'date': '2018-10-31',
#   'demography_type': '1',
#   'geomaster_id': 6163,
#   'geomaster_name': 'Turkana',
#   'households': '22632',
#   'individuals': '107672',
#   'individuals_type': '2',
#   'lat_max': 5.4253357903935,
#   'lat_min': 0.73885827173606,
#   'lon_max': 38.57773615,
#   'lon_min': 33.6744158375,
#   'month': '10',
#   'numChildren': '0',
#   'population_group_id': '4949',
#   'population_groups': [{'id': '4949',
#                          'name': 'Registered refugees from South Sudan  '
#                                  '(refugee camps/centers, UNHCR)',
#                          'pop_accommodation_code': 'C',
#                          'pop_accommodation_name': 'Refugee Camps/Centers',
#                          'pop_data_type_code': 'REG',
#                          'pop_data_type_name': 'Registered',
# ...

# %%
import json
from pprint import pprint

with open('refugees to Kenya per sex.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'chartType': 'areaspline',
#  'color': '#3c8dbc',
#  'data': [{'admin_level': 'Country',
#            'centroid_lat': '0.537253',
#            'centroid_lon': '37.8802',
#            'children_total': '72029',
#            'date': '2018-10-31',
#            'demography_type': '1',
#            'female_04': '7934',
#            'female_1217': '10126',
#            'female_1859': '20816',
#            'female_511': '14074',
#            'female_60': '985',
#            'female_hhs': '15789',
#            'female_total': '53935',
#            'geomaster_id': '178',
#            'geomaster_name': 'Kenya',
#            'households': '25412',
#            'individuals': '114391',
#            'individuals_type': '2',
#            'lat_max': '5.310256993246',
#            'lat_min': '-4.8009452089826',
#            'lon_max': '42.4192625',
#            'lon_min': '33.5608640625',
#            'male_04': '8301',
#            'male_1217': '15261',
#            'male_1859': '20195',
# ...

# %%
import json
from pprint import pprint

with open('refugees from south-sudan all.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'chartType': 'areaspline',
#  'color': '#3c8dbc',
#  'currentSeries': 1,
#  'data': {'source': 'UNHCR, Office of the Prime Minister, IOM, SRCS, COR, HAC',
#           'timeseries': [{'data_date': '2014-03-31',
#                           'individuals': 398264,
#                           'unix_timestamp': 1396224000},
#                          {'data_date': '2014-06-30',
#                           'individuals': 513868,
#                           'unix_timestamp': 1404086400},
#                          {'data_date': '2014-09-30',
#                           'individuals': 589560,
#                           'unix_timestamp': 1412035200},
#                          {'data_date': '2014-10-31',
#                           'individuals': 591356,
#                           'unix_timestamp': 1414713600},
#                          {'data_date': '2014-11-30',
#                           'individuals': 591356,
#                           'unix_timestamp': 1417305600},
# ...

# %%
import json
from pprint import pprint

with open('refugees to DRC per DRC region.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'chartType': 'areaspline',
#  'color': '#3c8dbc',
#  'data': [{'admin_level': 'Province',
#            'centroid_lat': '3.5845154',
#            'centroid_lon': '28.299435',
#            'color': '#3c8dbc',
#            'date': '2018-10-31',
#            'demography_type': '1',
#            'geomaster_id': 4826,
#            'geomaster_name': 'Haut-Uele',
#            'households': '0',
#            'individuals': '49554',
#            'individuals_type': '2',
#            'lat_max': 5.1866504417685,
#            'lat_min': 2.2763552727767,
#            'lon_max': 30.8623046875,
#            'lon_min': 26.55224609375,
#            'month': '10',
#            'numChildren': '0',
#            'population_group_id': '4949, 4768, 5075',
#            'population_groups': [{'id': '4768',
#                                   'name': 'Registered refugees from South '
#                                           'Sudan (rural/dispersed areas, '
# ...

# %%
import json
from pprint import pprint

with open('refugees to Ethiopia per Ethiopian district.json') as f:
    data = json.load(f)

pprint(data)
# Out:
# {'chartType': 'areaspline',
#  'color': '#3c8dbc',
#  'data': [{'admin_level': 'Region',
#            'centroid_lat': '7.83333',
#            'centroid_lon': '34.5',
#            'color': '#3c8dbc',
#            'date': '2018-08-31',
#            'demography_type': '1',
#            'geomaster_id': 1849,
#            'geomaster_name': 'Gambela',
#            'households': '0',
#            'individuals': '401507',
#            'individuals_type': '2',
#            'lat_max': 14.83333,
#            'lat_min': 0.83333,
#            'lon_max': 41.5,
#            'lon_min': 27.5,
#            'month': '8',
#            'numChildren': '17',
#            'population_group_id': '4949',
#            'population_groups': [{'id': '4949',
#                                   'name': 'Registered refugees from South '
#                                           'Sudan  (refugee camps/centers, '
#                                           'UNHCR)',
# ...
